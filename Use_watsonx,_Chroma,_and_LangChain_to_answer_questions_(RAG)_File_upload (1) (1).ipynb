# %%
# !pip install wget
# !pip install -U "langchain>=0.3,<0.4"
# !pip install -U "ibm_watsonx_ai>=1.1.22"
# !pip install -U "langchain_ibm>=0.3,<0.4"
# !pip install -U "langchain_chroma>=0.1,<0.2"
# !pip install PyPDF2
# Out:
# Requirement already satisfied: wget in c:\personal\aditya-project\myenv\lib\site-packages (3.2)
# Requirement already satisfied: langchain<0.4,>=0.3 in c:\personal\aditya-project\myenv\lib\site-packages (0.3.12)
# Requirement already satisfied: PyYAML>=5.3 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (3.11.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (0.3.25)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (0.2.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain<0.4,>=0.3) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\personal\aditya-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.4,>=0.3) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain<0.4,>=0.3) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain<0.4,>=0.3) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.25->langchain<0.4,>=0.3) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\personal\aditya-project\myenv\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\personal\aditya-project\myenv\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\personal\aditya-project\myenv\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\personal\aditya-project\myenv\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\personal\aditya-project\myenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4,>=0.3) (3.1.1)
# Requirement already satisfied: anyio in c:\personal\aditya-project\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\personal\aditya-project\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\personal\aditya-project\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain<0.4,>=0.3) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\personal\aditya-project\myenv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain<0.4,>=0.3) (1.3.1)
# Requirement already satisfied: ibm_watsonx_ai>=1.1.22 in c:\personal\aditya-project\myenv\lib\site-packages (1.1.26)
# Requirement already satisfied: requests in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (2.32.2)
# Requirement already satisfied: httpx in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (0.28.1)
# Requirement already satisfied: urllib3 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (2.2.3)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (2.1.4)
# Requirement already satisfied: certifi in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (2024.12.14)
# Requirement already satisfied: lomond in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (0.3.3)
# Requirement already satisfied: tabulate in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (0.9.0)
# Requirement already satisfied: packaging in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\personal\aditya-project\myenv\lib\site-packages (from ibm_watsonx_ai>=1.1.22) (8.5.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai>=1.1.22) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai>=1.1.22) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai>=1.1.22) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai>=1.1.22) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai>=1.1.22) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai>=1.1.22) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai>=1.1.22) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\personal\aditya-project\myenv\lib\site-packages (from requests->ibm_watsonx_ai>=1.1.22) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\personal\aditya-project\myenv\lib\site-packages (from requests->ibm_watsonx_ai>=1.1.22) (3.10)
# Requirement already satisfied: anyio in c:\personal\aditya-project\myenv\lib\site-packages (from httpx->ibm_watsonx_ai>=1.1.22) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\personal\aditya-project\myenv\lib\site-packages (from httpx->ibm_watsonx_ai>=1.1.22) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from httpcore==1.*->httpx->ibm_watsonx_ai>=1.1.22) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\personal\aditya-project\myenv\lib\site-packages (from importlib-metadata->ibm_watsonx_ai>=1.1.22) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in c:\personal\aditya-project\myenv\lib\site-packages (from lomond->ibm_watsonx_ai>=1.1.22) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\personal\aditya-project\myenv\lib\site-packages (from anyio->httpx->ibm_watsonx_ai>=1.1.22) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\personal\aditya-project\myenv\lib\site-packages (from anyio->httpx->ibm_watsonx_ai>=1.1.22) (4.12.2)
# Requirement already satisfied: langchain_ibm<0.4,>=0.3 in c:\personal\aditya-project\myenv\lib\site-packages (0.3.5)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.1.16 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_ibm<0.4,>=0.3) (1.1.26)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_ibm<0.4,>=0.3) (0.3.25)
# Requirement already satisfied: requests in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.32.2)
# Requirement already satisfied: httpx in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (0.28.1)
# Requirement already satisfied: urllib3 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.2.3)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.1.4)
# Requirement already satisfied: certifi in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2024.12.14)
# Requirement already satisfied: lomond in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (0.3.3)
# Requirement already satisfied: tabulate in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (0.9.0)
# Requirement already satisfied: packaging in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (8.5.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (0.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (4.12.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\personal\aditya-project\myenv\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\personal\aditya-project\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (1.0.0)
# Requirement already satisfied: anyio in c:\personal\aditya-project\myenv\lib\site-packages (from httpx->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\personal\aditya-project\myenv\lib\site-packages (from httpx->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (1.0.7)
# Requirement already satisfied: idna in c:\personal\aditya-project\myenv\lib\site-packages (from httpx->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from httpcore==1.*->httpx->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (0.14.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3.0->langchain_ibm<0.4,>=0.3) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\personal\aditya-project\myenv\lib\site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (3.4.0)
# Requirement already satisfied: zipp>=3.20 in c:\personal\aditya-project\myenv\lib\site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in c:\personal\aditya-project\myenv\lib\site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\personal\aditya-project\myenv\lib\site-packages (from anyio->httpx->ibm-watsonx-ai<2.0.0,>=1.1.16->langchain_ibm<0.4,>=0.3) (1.3.1)
# Requirement already satisfied: langchain_chroma<0.2,>=0.1 in c:\personal\aditya-project\myenv\lib\site-packages (0.1.4)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_chroma<0.2,>=0.1) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_chroma<0.2,>=0.1) (0.115.6)
# Requirement already satisfied: langchain-core<0.4,>=0.1.40 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_chroma<0.2,>=0.1) (0.3.25)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain_chroma<0.2,>=0.1) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.10.3)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\personal\aditya-project\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\personal\aditya-project\myenv\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (13.9.4)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\personal\aditya-project\myenv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma<0.2,>=0.1) (0.41.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in c:\personal\aditya-project\myenv\lib\site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\personal\aditya-project\myenv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.2.0)
# Requirement already satisfied: colorama in c:\personal\aditya-project\myenv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.4.6)
# Requirement already satisfied: anyio in c:\personal\aditya-project\myenv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.7.0)
# Requirement already satisfied: certifi in c:\personal\aditya-project\myenv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\personal\aditya-project\myenv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.0.7)
# Requirement already satisfied: idna in c:\personal\aditya-project\myenv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\personal\aditya-project\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.8.0)
# Requirement already satisfied: requests in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.32.2)
# Requirement already satisfied: requests-oauthlib in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\personal\aditya-project\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (1.0.0)
# Requirement already satisfied: coloredlogs in c:\personal\aditya-project\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\personal\aditya-project\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (24.3.25)
# Requirement already satisfied: protobuf in c:\personal\aditya-project\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (5.29.1)
# Requirement already satisfied: sympy in c:\personal\aditya-project\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in c:\personal\aditya-project\myenv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\personal\aditya-project\myenv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\personal\aditya-project\myenv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\personal\aditya-project\myenv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\personal\aditya-project\myenv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\personal\aditya-project\myenv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\personal\aditya-project\myenv\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.27.0)
# Requirement already satisfied: click>=8.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\personal\aditya-project\myenv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\personal\aditya-project\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\personal\aditya-project\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in c:\personal\aditya-project\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (14.1)
# Requirement already satisfied: sniffio>=1.1 in c:\personal\aditya-project\myenv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\personal\aditya-project\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\personal\aditya-project\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\personal\aditya-project\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.9)
# Requirement already satisfied: filelock in c:\personal\aditya-project\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\personal\aditya-project\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in c:\personal\aditya-project\myenv\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\personal\aditya-project\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\personal\aditya-project\myenv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\personal\aditya-project\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\personal\aditya-project\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\personal\aditya-project\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\personal\aditya-project\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.6.1)
# Requirement already satisfied: PyPDF2 in c:\personal\aditya-project\myenv\lib\site-packages (3.0.1)

# %%
import os
import getpass

from ibm_watsonx_ai import Credentials

credentials = Credentials(
    url="https://us-south.ml.cloud.ibm.com",
    api_key="9JAu6q17I5PwWYISP9HhsqvlygIkbygflVj6fZ74plwm",
)

# %%
try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = "97ea408b-8fee-4927-86e3-13fdc670ee98"

# %%
from ibm_watsonx_ai import APIClient

api_client = APIClient(credentials=credentials, project_id=project_id)

# %%
from IPython.display import display
import ipywidgets as widgets
import PyPDF2

# File upload widget
upload_widget = widgets.FileUpload(accept='.pdf,.txt', multiple=False)

# Function to process uploaded files
def process_uploaded_file(uploaded_file):
    for name, file_info in uploaded_file.value.items():
        file_content = file_info['content']
        if name.endswith('.pdf'):
            # Save and read PDF
            with open(name, 'wb') as f:
                f.write(file_content)
            with open(name, 'rb') as pdf_file:
                pdf_reader = PyPDF2.PdfReader(pdf_file)
                text = ""
                for page in pdf_reader.pages:
                    try:
                        # Attempt to extract text using UTF-8
                        text += page.extract_text()
                    except UnicodeDecodeError:
                        # If UTF-8 fails, try 'latin-1'
                        text += page.extract_text(encoding='latin-1')
            return text
        elif name.endswith('.txt'):
            # Read text file
            return file_content.decode('utf-8')
        else:
            raise ValueError("Unsupported file type. Please upload a .pdf or .txt file.")

# Display the upload widget
display(upload_widget)
# Out:
# FileUpload(value=(), accept='.pdf,.txt', description='Upload')

# %%
# Process the file if uploaded
uploaded_file = upload_widget.value
if uploaded_file:
    data = process_uploaded_file(upload_widget)
    print(f"Uploaded file processed: {len(data)} characters")
else:
    raise ValueError("No file uploaded!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 uploaded_file = upload_widget.value
#       3 if uploaded_file:
# ----> 4     data = process_uploaded_file(upload_widget)
#       5     print(f"Uploaded file processed: {len(data)} characters")
#       6 else:
#
# Cell In[5], line 10, in process_uploaded_file(uploaded_file)
#       9 def process_uploaded_file(uploaded_file):
# ---> 10     for name, file_info in uploaded_file.value.items():
#      11         file_content = file_info['content']
#      12         if name.endswith('.pdf'):
#      13             # Save and read PDF
#
# AttributeError: 'tuple' object has no attribute 'items'

# %%
from langchain.text_splitter import CharacterTextSplitter

# Split the text into smaller chunks for vectorization
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_text(data)
print(f"Text split into {len(texts)} chunks.")
# Out:
# Text split into 1 chunks.

# %%
# !pip install -U "langchain_chroma>=0.1,<0.2"
from langchain_chroma import Chroma
from langchain_ibm import WatsonxEmbeddings
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Initialize Watsonx embeddings
embeddings = WatsonxEmbeddings(
    model_id="ibm/slate-30m-english-rtrvr",
    url=credentials["url"],
    apikey=credentials["apikey"],
    project_id=project_id
)

# Use RecursiveCharacterTextSplitter for better handling of long text
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=512,  # Set chunk size considering the model's max sequence length
    chunk_overlap=0,
    length_function=len,  # Use len to count characters
)
texts = text_splitter.split_text(data)

# Convert the text chunks into Document objects
documents = [Document(page_content=text) for text in texts]

# Create a vector store for document retrieval
docsearch = Chroma.from_documents(documents, embeddings)
print("Embeddings generated and stored in Chroma.")
# Out:
# Collecting langchain_chroma<0.2,>=0.1
#   Using cached langchain_chroma-0.1.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 (from langchain_chroma<0.2,>=0.1)
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain_chroma<0.2,>=0.1)
#   Using cached fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.1.40 in /usr/local/lib/python3.10/dist-packages (from langchain_chroma<0.2,>=0.1) (0.3.25)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_chroma<0.2,>=0.1) (1.26.4)
# Collecting build>=1.0.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.10.3)
# Collecting chroma-hnswlib==0.7.6 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting posthog>=2.4.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached posthog-3.7.4-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.66.6)
# Collecting overrides>=7.3.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.68.1)
# Collecting bcrypt>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (13.9.4)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi<1,>=0.95.2->langchain_chroma<0.2,>=0.1)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.32.2)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.1.40->langchain_chroma<0.2,>=0.1) (1.0.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.50b0)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.17.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.26.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading watchfiles-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (14.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (3.4.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma<0.2,>=0.1) (0.6.1)
# Downloading langchain_chroma-0.1.4-py3-none-any.whl (10 kB)
# Downloading chromadb-0.5.23-py3-none-any.whl (628 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 19.6 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 87.8 MB/s eta 0:00:00
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.5 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 26.9 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 75.1 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 10.1 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 100.4 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.6 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.4-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 5.7 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 7.7 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.5 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 39.7 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 26.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.0 MB/s eta 0:00:00
# Downloading watchfiles-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.8/443.8 kB 40.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.5 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=7105c85bc417a4377d35ca9bb3a63bb2169ee67d9b35aa4d4f6a7774092565c3
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, uvloop, uvicorn, python-dotenv, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-proto, coloredlogs, build, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb, langchain_chroma
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5

# %%
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import DecodingMethods
from langchain_ibm import WatsonxLLM

# Define model type and parameters
model_id = ModelTypes.GRANITE_13B_CHAT_V2
parameters = {
    GenParams.DECODING_METHOD: DecodingMethods.GREEDY,
    GenParams.MIN_NEW_TOKENS: 1,
    GenParams.MAX_NEW_TOKENS: 100,
    GenParams.STOP_SEQUENCES: ["<|endoftext|>"]
}

# Initialize the Granite model
watsonx_granite = WatsonxLLM(
    model_id=model_id.value,
    url=credentials.get("url"),
    apikey=credentials.get("apikey"),
    project_id=project_id,
    params=parameters
)
print("Watsonx Granite model initialized.")

# %%
from langchain.chains import RetrievalQA

# Build RetrievalQA using the vector store and Granite model
qa = RetrievalQA.from_chain_type(llm=watsonx_granite, chain_type="stuff", retriever=docsearch.as_retriever())
print("Question answering system initialized.")

# %%
# Example query
query = "which kind of campaigns sachin had worked ?"
response = qa.invoke(query)
print(f"Answer: {response}")
